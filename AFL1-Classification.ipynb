# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Loading

# %%
# Load Dataset
url = "D:/Assignments/Semester-5/ML/AFL1/Data/gallstone_data.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    patientId  Gallstone Status  Age  Gender  Comorbidity  \
# 0         73                 0   61       0            1
# 1         46                 0   23       0            0
# 2         97                 0   72       1            1
# 3        179                 1   30       0            0
# 4         44                 0   60       0            1
#
#    Coronary Artery Disease (CAD)  Hypothyroidism  Hyperlipidemia  \
# 0                              0               0               0
# 1                              0               0               0
# 2                              0               0               0
# 3                              0               0               0
# 4                              0               0               0
#
#    Diabetes Mellitus (DM)  Height  ...  High Density Lipoprotein (HDL)  \
# 0                       0     170  ...                            52.0
# 1                       0     180  ...                            35.0
# 2                       1     150  ...                            48.0
# 3                       0     172  ...                            42.0
# 4                       0     175  ...                            41.0
#
#    Triglyceride  Aspartat Aminotransferaz (AST)  Alanin Aminotransferaz (ALT)  \
# 0          77.0                            19.0                          19.0
# 1          93.0                            47.0                          33.0
# 2         244.0                            11.0                          12.0
# 3         125.0                            22.0                          46.0
# 4          70.0                            20.0                          28.0
#
#    Alkaline Phosphatase (ALP)  Creatinine  Glomerular Filtration Rate (GFR)  \
# 0                        52.0        1.14                             79.85
# 1                        65.0        0.91                            121.45
# 2                        81.0        0.70                              92.4
# 3                        66.0        0.80                               122
# 4                       115.0        0.90                             97.16
#
#    C-Reactive Protein (CRP)  Hemoglobin (HGB)  Vitamin D
# 0                      0.13              14.6        6.8
# 1                      1.04              15.1      26.98
# 2                      0.52              15.1       12.4
# 3                      0.00              18.2       24.5
# 4                      1.54              13.8      29.02
#
# [5 rows x 40 columns]

# %%
# Dataset Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 40 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   patientId                                       244 non-null    int64
#  1   Gallstone Status                                244 non-null    int64
#  2   Age                                             244 non-null    int64
#  3   Gender                                          244 non-null    int64
#  4   Comorbidity                                     244 non-null    int64
#  5   Coronary Artery Disease (CAD)                   244 non-null    int64
#  6   Hypothyroidism                                  244 non-null    int64
#  7   Hyperlipidemia                                  244 non-null    int64
#  8   Diabetes Mellitus (DM)                          244 non-null    int64
#  9   Height                                          244 non-null    int64
#  10  Weight                                          244 non-null    float64
#  11  Body Mass Index (BMI)                           244 non-null    float64
#  12  Total Body Water (TBW)                          244 non-null    float64
#  13  Extracellular Water (ECW)                       244 non-null    float64
#  14  Intracellular Water (ICW)                       244 non-null    float64
#  15  Extracellular Fluid/Total Body Water (ECF/TBW)  244 non-null    float64
#  16  Total Body Fat Ratio (TBFR) (%)                 244 non-null    float64
#  17  Lean Mass (LM) (%)                              244 non-null    float64
#  18  Body Protein Content (Protein) (%)              244 non-null    float64
#  19  Visceral Fat Rating (VFR)                       244 non-null    int64
#  20  Bone Mass (BM)                                  244 non-null    float64
#  21  Muscle Mass (MM)                                244 non-null    float64
#  22  Obesity (%)                                     244 non-null    float64
#  23  Total Fat Content (TFC)                         244 non-null    float64
#  24  Visceral Fat Area (VFA)                         244 non-null    float64
#  25  Visceral Muscle Area (VMA) (Kg)                 244 non-null    object
#  26  Hepatic Fat Accumulation (HFA)                  244 non-null    int64
#  27  Glucose                                         244 non-null    float64
#  28  Total Cholesterol (TC)                          244 non-null    float64
#  29  Low Density Lipoprotein (LDL)                   244 non-null    float64
#  30  High Density Lipoprotein (HDL)                  244 non-null    float64
#  31  Triglyceride                                    244 non-null    float64
#  32  Aspartat Aminotransferaz (AST)                  244 non-null    float64
#  33  Alanin Aminotransferaz (ALT)                    244 non-null    float64
#  34  Alkaline Phosphatase (ALP)                      244 non-null    float64
#  35  Creatinine                                      244 non-null    float64
#  36  Glomerular Filtration Rate (GFR)                244 non-null    object
#  37  C-Reactive Protein (CRP)                        244 non-null    float64
#  38  Hemoglobin (HGB)                                244 non-null    float64
#  39  Vitamin D                                       244 non-null    object
# dtypes: float64(25), int64(12), object(3)
# memory usage: 76.4+ KB

# %%
# Dataset Statistical Information
df.describe()
# Out:
#         patientId  Gallstone Status         Age      Gender  Comorbidity  \
# count  244.000000        244.000000  244.000000  244.000000   244.000000
# mean   155.635246          0.471311   48.241803    0.504098     0.336066
# std     90.563225          0.500202   11.889881    0.501011     0.530714
# min      1.000000          0.000000   20.000000    0.000000     0.000000
# 25%     78.500000          0.000000   39.750000    0.000000     0.000000
# 50%    154.500000          0.000000   50.000000    1.000000     0.000000
# 75%    231.250000          1.000000   56.000000    1.000000     1.000000
# max    319.000000          1.000000   96.000000    1.000000     3.000000
#
#        Coronary Artery Disease (CAD)  Hypothyroidism  Hyperlipidemia  \
# count                     244.000000      244.000000      244.000000
# mean                        0.045082        0.028689        0.020492
# std                         0.207910        0.167273        0.141967
# min                         0.000000        0.000000        0.000000
# 25%                         0.000000        0.000000        0.000000
# 50%                         0.000000        0.000000        0.000000
# 75%                         0.000000        0.000000        0.000000
# max                         1.000000        1.000000        1.000000
#
#        Diabetes Mellitus (DM)      Height  ...  Total Cholesterol (TC)  \
# count              244.000000  244.000000  ...              244.000000
# mean                 0.131148  166.819672  ...              205.706967
# std                  0.338256    9.814759  ...               45.942633
# min                  0.000000  146.000000  ...               60.000000
# 25%                  0.000000  159.000000  ...              172.750000
# 50%                  0.000000  168.000000  ...              199.500000
# 75%                  0.000000  175.000000  ...              235.250000
# max                  1.000000  191.000000  ...              360.000000
#
#        Low Density Lipoprotein (LDL)  High Density Lipoprotein (HDL)  \
# count                     244.000000                      244.000000
# mean                      128.410246                       50.094262
# std                        38.235384                       19.194621
# min                        28.000000                       25.000000
# 25%                       102.000000                       40.000000
# 50%                       123.000000                       47.000000
# 75%                       151.000000                       57.000000
# max                       293.000000                      273.000000
#
#        Triglyceride  Aspartat Aminotransferaz (AST)  \
# count    244.000000                      244.000000
# mean     140.608156                       21.227459
# std       90.566461                       14.223036
# min        1.390000                        8.000000
# 25%       81.000000                       15.000000
# 50%      118.000000                       18.000000
# 75%      168.750000                       23.250000
# max      692.000000                      195.000000
#
#        Alanin Aminotransferaz (ALT)  Alkaline Phosphatase (ALP)  Creatinine  \
# count                    244.000000                  244.000000  244.000000
# mean                      26.686475                   73.372951    6.699180
# std                       28.719393                   24.552418   64.980661
# min                        3.000000                    7.000000    0.460000
# 25%                       15.000000                   58.000000    0.650000
# 50%                       19.000000                   71.000000    0.790000
# 75%                       28.250000                   87.250000    0.940000
# max                      372.000000                  197.000000  725.000000
#
#        C-Reactive Protein (CRP)  Hemoglobin (HGB)
# count                244.000000        244.000000
# mean                   3.880697         14.346721
# std                   24.683293          1.815494
# min                    0.000000          8.500000
# 25%                    0.000000         13.275000
# 50%                    0.215000         14.400000
# 75%                    1.470000         15.600000
# max                  315.000000         18.800000
#
# [8 rows x 37 columns]

# %% [markdown]
# ## Data Cleansing

# %%
# VMA Data Cleaning
def clean_vma(value):
    try:
        digits = str(value).replace('.', '')
        num_digits = len(digits)

        if num_digits == 3: 
            return float(digits) / 10.0
        elif num_digits >= 4: 
            return float(digits[:4]) / 100.0
        else: 
            return float(digits)
    except (ValueError, TypeError):
        return np.nan 

vma = df.copy()
vma['Visceral Muscle Area (VMA) (Kg)'] = vma['Visceral Muscle Area (VMA) (Kg)'].apply(clean_vma)

cleaned_file_path = "D:/Assignments/Semester-5/ML/AFL1/Data/gallstone_data_cleaned.csv"
vma.to_csv(cleaned_file_path, index=False)

df = vma

# %%
# GFR Data Cleaning
def clean_gfr(value):
    try:
        stringValue = str(value)
        digits = stringValue.replace('.', '')
        num_digits = len(digits)

        if num_digits >= 6: 
            if digits.startswith('1'):
                return float(digits[:5]) / 100.0
            else:
                return float(digits[:4]) / 100.0
        else: 
            return float(stringValue)
    except (ValueError, TypeError):
        return np.nan
    
gfr = df.copy()
gfr['Glomerular Filtration Rate (GFR)'] = gfr['Glomerular Filtration Rate (GFR)'].apply(clean_gfr)

cleaned_file_path = "D:/Assignments/Semester-5/ML/AFL1/Data/gallstone_data_cleaned.csv"

gfr.to_csv(cleaned_file_path, index=False)

df = gfr

# %%
# Vitamin D Data Cleaning
def clean_vitamin_d(value):
    try:
        stringValue = str(value)
        digits = stringValue.replace('.', '')
        num_digits = len(digits)

        if num_digits >= 4: 
            return float(digits[:4]) / 100.0
        else: 
            return float(stringValue)
    except (ValueError, TypeError):
        return np.nan 

vd = df.copy()
vd['Vitamin D'] = vd['Vitamin D'].apply(clean_vitamin_d)

cleaned_file_path = "D:/Assignments/Semester-5/ML/AFL1/Data/gallstone_data_cleaned.csv"
vd.to_csv(cleaned_file_path, index=False)

df = vd

# %%
# Visualizations (VMA, GFR, Vitamin D)
columns_to_plot = ['Visceral Muscle Area (VMA) (Kg)', 'Glomerular Filtration Rate (GFR)', 'Vitamin D']

for col in columns_to_plot:
        plt.figure(figsize=(15, 6))

        # 1. Box Plot
        plt.subplot(1, 2, 1) 
        sns.boxplot(x=df[col])
        plt.title(f'Box Plot of {col}')
        plt.xlabel(col)

        # 2. Histogram
        plt.subplot(1, 2, 2) 
        sns.histplot(df[col], kde=True, bins=30) 
        plt.title(f'Histogram of {col}')
        plt.xlabel(col)

        plt.suptitle(f'Outlier Analysis for {col}', fontsize=16)
        plt.tight_layout(rect=[0, 0.03, 1, 0.95]) 
        plt.show()

# %% [markdown]
# ## Data Engineering

# %%
# Feature Selection
import json

x = df.drop(['patientId', 'Gallstone Status'], axis=1)
y = df['Gallstone Status']

training_columns = x.columns.tolist()

with open('training_columns.json', 'w') as f:
    json.dump(training_columns, f)

print("Training columns saved to training_columns.json")
# Out:
# Training columns saved to training_columns.json

# %%
# Data Splitting
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(f"Training set size: {x_train.shape[0]} samples")
print(f"Testing set size: {x_test.shape[0]} samples")
# Out:
# Training set size: 195 samples
# Testing set size: 49 samples

# %%
# Data Clipping
numerical_cols = x_train.select_dtypes(include=np.number).columns
cols_to_exclude = ['Gender', 'Comorbidity', 'Coronary Artery Disease (CAD)', 
                   'Hypothyroidism', 'Hyperlipidemia', 'Diabetes Mellitus (DM)', 
                   'Hepatic Fat Accumulation (HFA)']
cols_to_clip = [col for col in numerical_cols if col not in cols_to_exclude]

for col in cols_to_clip:
    lower_bound = df[col].quantile(0.01)
    upper_bound = df[col].quantile(0.99)
    
    df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)

print("Outlier clipping complete")
# Out:
# Outlier clipping complete

# %%
# Feature Engineering
df['AST_ALT_Ratio'] = df['Aspartat Aminotransferaz (AST)'] / df['Alanin Aminotransferaz (ALT)']

df['TC_HDL_Ratio'] = df['Total Cholesterol (TC)'] / df['High Density Lipoprotein (HDL)']

df['Age_x_Triglyceride'] = df['Age'] * df['Triglyceride']

df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.fillna(0, inplace=True) 

print(df[['AST_ALT_Ratio', 'TC_HDL_Ratio', 'Age_x_Triglyceride']].head())
# Out:
#    AST_ALT_Ratio  TC_HDL_Ratio  Age_x_Triglyceride
# 0       1.000000      3.288462              4697.0
# 1       1.424242      4.771429              2139.0
# 2       0.916667      5.729167             17568.0
# 3       0.478261      4.595238              3750.0
# 4       0.714286      5.634146              4200.0

# %% [markdown]
# ## Model Training

# %%
# Model Training
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV
from sklearn.impute import SimpleImputer
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.metrics import accuracy_score, classification_report
import joblib

stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler()),
    ('classifier', XGBClassifier(random_state=42, eval_metric='logloss'))
])

param_dist = {
    'classifier__n_estimators': [100, 200, 300],
    'classifier__max_depth': [3, 4, 5, 7],
    'classifier__learning_rate': [0.01, 0.05, 0.1, 0.2],
    'classifier__subsample': [0.7, 0.8, 1.0],
    'classifier__colsample_bytree': [0.7, 0.8, 1.0]
}

sample_weights = compute_sample_weight(class_weight='balanced', y=y_train)

random_search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_dist,
    n_iter=50,
    cv=stratified_kfold,
    n_jobs=-1,
    verbose=2,
    random_state=42
)

random_search.fit(x_train, y_train, classifier__sample_weight=sample_weights)

print("Best parameters found: ", random_search.best_params_)

best_model = random_search.best_estimator_

y_pred = best_model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"\nFinal Tuned Model Accuracy: {accuracy * 100:.2f}%")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

joblib.dump(best_model, 'model.joblib')
print("\nComplete pipeline model saved to model.joblib")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'classifier__subsample': 0.8, 'classifier__n_estimators': 100, 'classifier__max_depth': 7, 'classifier__learning_rate': 0.2, 'classifier__colsample_bytree': 1.0}
#
# Final Tuned Model Accuracy: 81.63%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82        25
#            1       0.80      0.83      0.82        24
#
#     accuracy                           0.82        49
#    macro avg       0.82      0.82      0.82        49
# weighted avg       0.82      0.82      0.82        49
#
#
# Complete pipeline model saved to model.joblib

# %%
# Feature Importance 
import matplotlib.pyplot as plt
import seaborn as sns

importances = best_model.named_steps['classifier'].feature_importances_
feature_names = x.columns

feature_importance_df = pd.DataFrame({'feature': feature_names, 'importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)

plt.figure(figsize=(12, 10))
sns.barplot(x='importance', y='feature', data=feature_importance_df.head(15)) 
plt.title('Top 15 Most Important Features for Predicting Gallstones')
plt.xlabel('Importance Score')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Testing

# %%
# Final Prediction 
import pandas as pd
import numpy as np
import joblib
import json

pipeline = joblib.load('model.joblib')

with open('training_columns.json', 'r') as f:
    training_columns = json.load(f)

test_df = pd.read_csv('D:/Assignments/Semester-5/ML/AFL1/Data/gallstone_test.csv')

test_df['Visceral Muscle Area (VMA) (Kg)'] = test_df['Visceral Muscle Area (VMA) (Kg)'].apply(clean_vma)
test_df['Glomerular Filtration Rate (GFR)'] = test_df['Glomerular Filtration Rate (GFR)'].apply(clean_gfr)
test_df['Vitamin D'] = test_df['Vitamin D'].apply(clean_vitamin_d)

test_df['AST_ALT_Ratio'] = test_df['Aspartat Aminotransferaz (AST)'] / test_df['Alanin Aminotransferaz (ALT)']
test_df['TC_HDL_Ratio'] = test_df['Total Cholesterol (TC)'] / test_df['High Density Lipoprotein (HDL)']
test_df['Age_x_Triglyceride'] = test_df['Age'] * test_df['Triglyceride']
test_df.replace([np.inf, -np.inf], np.nan, inplace=True)
test_df.fillna(0, inplace=True)

X_new_test = test_df[training_columns]

predictions = pipeline.predict(X_new_test)

output_df = pd.DataFrame({
    'patientId': test_df['patientId'],
    'Gallstone Status': predictions
})

output_filename = 'D:/Assignments/Semester-5/ML/AFL1/Data/gallstone_predictions.csv'
output_df.to_csv(output_filename, index=False)

print(f"Predictions successfully saved to {output_filename}")
print("\nSaved file preview:")
print(output_df.head())
# Out:
# Predictions successfully saved to D:/Assignments/Semester-5/ML/AFL1/Data/gallstone_predictions.csv
#
# Saved file preview:
#    patientId  Gallstone Status
# 0        124                 0
# 1        316                 0
# 2         48                 0
# 3        272                 1
# 4        297                 1

# %%
# Prediction Count
import pandas as pd

predictions_df = pd.read_csv('D:/Assignments/Semester-5/ML/AFL1/Data/gallstone_predictions.csv')

print(predictions_df['Gallstone Status'].value_counts())
# Out:
# Gallstone Status
# 1    38
# 0    37
# Name: count, dtype: int64
